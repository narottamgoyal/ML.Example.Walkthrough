# %% [markdown]
# ## 1. Remove Stopword using NLTK

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\NAROT\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# set of stop words
nltk_stop_words = set(stopwords.words('english'))

# %%
nltk_stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
text = '''Google News is a news aggregator service developed by Google. It presents a continuous
flow of articles organized from thousands of publishers and magazines. Google News is available as 
an app on Android, iOS, and the Web. Google released a beta version in September 2002 and the 
official app in January 2006. Wikipedia'''

# %%
# tokens of words  
word_tokens = word_tokenize(text) 
    
cleaned_words = [] 
  
for w in word_tokens: 
    if w not in nltk_stop_words: 
        cleaned_words.append(w)

# %%
print("\n\nOriginal \n\n")
print(" ".join(word_tokens)) 

print("\n\cleaned\n\n")
print(" ".join(cleaned_words))
# Out:
# Original
#
#
# Google News is a news aggregator service developed by Google . It presents a continuous flow of articles organized from thousands of publishers and magazines . Google News is available as an app on Android , iOS , and the Web . Google released a beta version in September 2002 and the official app in January 2006 . Wikipedia
#
# \cleaned
#
#
# Google News news aggregator service developed Google . It presents continuous flow articles organized thousands publishers magazines . Google News available app Android , iOS , Web . Google released beta version September 2002 official app January 2006 . Wikipedia

# %% [markdown]
# ## 2. Remove Stopword using spaCy

# %%
from spacy.lang.en import English

# %%
nlp = English()

# %%
text = '''In 1729, Benjamin Franklin began writing a new form of newspaper that was more satirical 
and more involved in civic affairs than previously seen. In 1735, John Peter Zenger was accused 
of seditious libel by the governor of New York, William Cosby. Zenger was found not guilty,
largely in part to his attorney Andrew Hamilton, who later wrote a paper in which he argued 
that newspapers should be free to criticize the government as long as it was true. Later, with 
the ratification of the Bill of Rights in 1791, freedom of the press would be guaranteed by the
First Amendment'''

# %%
my_doc = nlp(text)
token_list = []
for token in my_doc:
    token_list.append(token.text)

# %%
token_list
# Out:
# ['In',
#  '1729',
#  ',',
#  'Benjamin',
#  'Franklin',
#  'began',
#  'writing',
#  'a',
#  'new',
#  'form',
#  'of',
#  'newspaper',
#  'that',
#  'was',
#  'more',
#  'satirical',
#  '\n',
#  'and',
#  'more',
#  'involved',
#  'in',
#  'civic',
#  'affairs',
#  'than',
#  'previously',
#  'seen',
#  '.',
#  'In',
#  '1735',
#  ',',
#  'John',
#  'Peter',
#  'Zenger',
#  'was',
#  'accused',
#  '\n',
#  'of',
#  'seditious',
#  'libel',
#  'by',
#  'the',
#  'governor',
#  'of',
#  'New',
#  'York',
#  ',',
#  'William',
#  'Cosby',
#  '.',
#  'Zenger',
#  'was',
#  'found',
#  'not',
#  'guilty',
#  ',',
#  '\n',
#  'largely',
#  'in',
#  'part',
#  'to',
#  'his',
#  'attorney',
#  'Andrew',
#  'Hamilton',
#  ',',
#  'who',
#  'later',
#  'wrote',
#  'a',
#  'paper',
#  'in',
#  'which',
#  'he',
#  'argued',
#  '\n',
#  'that',
#  'newspapers',
#  'should',
#  'be',
#  'free',
#  'to',
#  'criticize',
#  'the',
#  'government',
#  'as',
#  'long',
#  'as',
#  'it',
#  'was',
# ...

# %%
from spacy.lang.en.stop_words import STOP_WORDS as spacy_stop_words

# %%
spacy_stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
# ...

# %%
cleaned_words =[] 

for word in token_list :
    if word not in spacy_stop_words: 
        cleaned_words.append(word)

# %%
print(token_list)
# Out:
# ['In', '1729', ',', 'Benjamin', 'Franklin', 'began', 'writing', 'a', 'new', 'form', 'of', 'newspaper', 'that', 'was', 'more', 'satirical', '\n', 'and', 'more', 'involved', 'in', 'civic', 'affairs', 'than', 'previously', 'seen', '.', 'In', '1735', ',', 'John', 'Peter', 'Zenger', 'was', 'accused', '\n', 'of', 'seditious', 'libel', 'by', 'the', 'governor', 'of', 'New', 'York', ',', 'William', 'Cosby', '.', 'Zenger', 'was', 'found', 'not', 'guilty', ',', '\n', 'largely', 'in', 'part', 'to', 'his', 'attorney', 'Andrew', 'Hamilton', ',', 'who', 'later', 'wrote', 'a', 'paper', 'in', 'which', 'he', 'argued', '\n', 'that', 'newspapers', 'should', 'be', 'free', 'to', 'criticize', 'the', 'government', 'as', 'long', 'as', 'it', 'was', 'true', '.', 'Later', ',', 'with', '\n', 'the', 'ratification', 'of', 'the', 'Bill', 'of', 'Rights', 'in', '1791', ',', 'freedom', 'of', 'the', 'press', 'would', 'be', 'guaranteed', 'by', 'the', '\n', 'First', 'Amendment']

# %%
print(" ".join(cleaned_words))
# Out:
# In 1729 , Benjamin Franklin began writing new form newspaper satirical
#  involved civic affairs previously seen . In 1735 , John Peter Zenger accused
#  seditious libel governor New York , William Cosby . Zenger found guilty ,
#  largely attorney Andrew Hamilton , later wrote paper argued
#  newspapers free criticize government long true . Later ,
#  ratification Bill Rights 1791 , freedom press guaranteed
#  First Amendment

# %% [markdown]
# ## 3. Remove Stopword using Gensim

# %%
from gensim.parsing.preprocessing import remove_stopwords

# %%
text = '''Press" is the collective designation of media vehicles that carry out journalism and other
functions of informative communication, in contrast to pure propaganda or entertainment communication.
The term press comes from the printing press of Johannes Gutenberg in the sixteenth century and which,
from the eighteenth century, was used to print newspapers, then the only existing journalistic 
vehicles. From the middle of the 20th century onwards, newspapers also began to be broadcast (radio
news and television news).'''

# %%
result = remove_stopwords(text)

# %%
print('\n\n cleaned\n\n')
print(result)
# Out:
#  cleaned
#
#
# Press" collective designation media vehicles carry journalism functions informative communication, contrast pure propaganda entertainment communication. The term press comes printing press Johannes Gutenberg sixteenth century which, eighteenth century, print newspapers, existing journalistic vehicles. From middle 20th century onwards, newspapers began broadcast (radio news television news).
